# %% [markdown]
# # Schools in Poland

# %% [markdown]
# ## Loading data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('data/szkoly2024.xlsx')

# %% [markdown]
# ## Basic operations

# %%
df.head()
# Out:
#   Rok szkolny  idTerytWojewodztwo   Wojewodztwo  idTerytPowiat         Powiat  \
# 0   2024/2025                   2  DOLNOŚLĄSKIE            201  bolesławiecki
# 1   2024/2025                   2  DOLNOŚLĄSKIE            201  bolesławiecki
# 2   2024/2025                   2  DOLNOŚLĄSKIE            201  bolesławiecki
# 3   2024/2025                   2  DOLNOŚLĄSKIE            201  bolesławiecki
# 4   2024/2025                   2  DOLNOŚLĄSKIE            201  bolesławiecki
#
#    idTerytGmina        Gmina Typ gminy  Miejscowość  Czy szkoła  ...  \
# 0        201011  Bolesławiec         M  Bolesławiec           0  ...
# 1        201011  Bolesławiec         M  Bolesławiec           1  ...
# 2        201011  Bolesławiec         M  Bolesławiec           1  ...
# 3        201011  Bolesławiec         M  Bolesławiec           0  ...
# 4        201011  Bolesławiec         M  Bolesławiec           1  ...
#
#      Organ rejestrujący  ucz_ogolem  w tym_ucz_dziewczeta  \
# 0  POWIAT BOLESŁAWIECKI         NaN                   NaN
# 1  POWIAT BOLESŁAWIECKI         8.0                   5.0
# 2  POWIAT BOLESŁAWIECKI       499.0                 378.0
# 3  POWIAT BOLESŁAWIECKI         NaN                   NaN
# 4  POWIAT BOLESŁAWIECKI        60.0                  38.0
#
#   w tym_w oddz_przedszk  lb_oddz  etatUmowa w tym_etat_niepełnozatr  \
# 0                   NaN      NaN      47.33                    6.33
# 1                   NaN      1.0        NaN                     NaN
# 2                   NaN     18.0        NaN                     NaN
# 3                   NaN      NaN        NaN                     NaN
# 4                   NaN      2.0        NaN                     NaN
#
#    lb_naucz_osoby w tym_lb_naucz_pelnozatr w tym_lb_naucz_niepelnozatr
# 0            56.0                     41.0                        15.0
# 1             NaN                      NaN                         NaN
# 2             NaN                      NaN                         NaN
# 3             NaN                      NaN                         NaN
# 4             NaN                      NaN                         NaN
#
# [5 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55645 entries, 0 to 55644
# Data columns (total 58 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rok szkolny                        55645 non-null  object
#  1   idTerytWojewodztwo                 55645 non-null  int64
#  2   Wojewodztwo                        55645 non-null  object
#  3   idTerytPowiat                      55645 non-null  int64
#  4   Powiat                             55645 non-null  object
#  5   idTerytGmina                       55645 non-null  int64
#  6   Gmina                              55645 non-null  object
#  7   Typ gminy                          55645 non-null  object
#  8   Miejscowość                        55645 non-null  object
#  9   Czy szkoła                         55645 non-null  int64
#  10  idPodmiotGlowny                    55645 non-null  int64
#  11  idPodmiotNadrzedny                 16289 non-null  float64
#  12  idTypPodmiotuNadrzednego           16289 non-null  float64
#  13  Typ podmiotu nadrzędnego           16289 non-null  object
#  14  RSPO                               55645 non-null  int64
#  15  idTypPodmiotu                      55645 non-null  int64
#  16  Typ podmiotu                       55645 non-null  object
#  17  idRodzajPlacowki                   55645 non-null  int64
#  18  Rodzaj szkoły/placówki             55645 non-null  object
#  19  Nazwa placówki                     55645 non-null  object
#  20  Ulica                              46392 non-null  object
#  21  Numer domu                         55645 non-null  object
#  22  Numer lokalu                       2631 non-null   object
#  23  Kod pocztowy                       55645 non-null  object
#  24  Poczta                             55645 non-null  object
#  25  Adres www                          41471 non-null  object
#  26  regon                              55645 non-null  int64
#  27  idPublicznosc                      55645 non-null  int64
#  28  Publiczność                        55645 non-null  object
#  29  idKategoriaUczniow                 55645 non-null  int64
#  30  Kategoria uczniów                  55645 non-null  object
#  31  idSpecyfikaSzkoly                  55645 non-null  int64
#  32  Specyfika szkoły                   55645 non-null  object
#  33  idZwiazanieOrganizacyjneSzkoly     42447 non-null  float64
#  34  Związanie organizacyjne            42447 non-null  object
#  35  idTypOrgProw                       55645 non-null  int64
#  36  Typ organu prowadzącego            55645 non-null  object
#  37  typ_org_prow                       55645 non-null  object
#  38  idOrganProwadzacy                  55645 non-null  object
#  39  Organ prowadzący                   55645 non-null  object
#  40  idTerytWojewOrgRej                 54364 non-null  float64
#  41  Organ rejestrującey - województwo  54364 non-null  object
#  42  idTerytPowiatOrgRej                53357 non-null  float64
#  43  Organ rejestrujący - powiat        53357 non-null  object
#  44  idTerytGminaOrgRej                 41758 non-null  float64
#  45  Organ rejestrujący - gmina         41758 non-null  object
#  46  idTypOrgRej                        55645 non-null  int64
#  47  Typ organu rejestrującego          55645 non-null  object
#  48  Organ rejestrujący                 55645 non-null  object
#  49  ucz_ogolem                         39207 non-null  float64
#  50  w tym_ucz_dziewczeta               38654 non-null  float64
#  51  w tym_w oddz_przedszk              22279 non-null  float64
#  52  lb_oddz                            39207 non-null  float64
#  53  etatUmowa                          30298 non-null  float64
#  54  w tym_etat_niepełnozatr            30298 non-null  float64
#  55  lb_naucz_osoby                     30298 non-null  float64
#  56  w tym_lb_naucz_pelnozatr           30298 non-null  float64
#  57  w tym_lb_naucz_niepelnozatr        30298 non-null  float64
# dtypes: float64(15), int64(14), object(29)
# memory usage: 24.6+ MB

# %%
df.describe()
# Out:
#        idTerytWojewodztwo  idTerytPowiat  idTerytGmina    Czy szkoła  \
# count        55645.000000   55645.000000  5.564500e+04  55645.000000
# mean            16.854704    1715.113739  1.715147e+06      0.762494
# std              8.899294     890.306554  8.903056e+05      0.425558
# min              2.000000     201.000000  2.010110e+05      0.000000
# 25%             10.000000    1061.000000  1.061011e+06      1.000000
# 50%             14.000000    1465.000000  1.465011e+06      1.000000
# 75%             24.000000    2465.000000  2.465011e+06      1.000000
# max             32.000000    3263.000000  3.263011e+06      1.000000
#
#        idPodmiotGlowny  idPodmiotNadrzedny  idTypPodmiotuNadrzednego  \
# count     55645.000000        16289.000000              16289.000000
# mean     103529.285974        80211.179385                 92.914421
# std      116489.221983       103628.604896                 19.170467
# min        2869.000000         3021.000000                  3.000000
# 25%       22140.000000        15397.000000                100.000000
# 50%       62599.000000        38568.000000                100.000000
# 75%      126200.000000       105373.000000                100.000000
# max      483265.000000       482504.000000                100.000000
#
#                 RSPO  idTypPodmiotu  idRodzajPlacowki  ...   idTypOrgRej  \
# count   55645.000000   55645.000000      55645.000000  ...  55645.000000
# mean   107185.283925      30.074005          3.246437  ...    130.638063
# std    112028.259452      37.420464          2.796071  ...      1.482899
# min      2869.000000       1.000000          1.000000  ...    120.000000
# 25%     27822.000000       1.000000          1.000000  ...    130.000000
# 50%     74291.000000       3.000000          1.000000  ...    131.000000
# 75%    125433.000000      74.000000          7.000000  ...    131.000000
# max    483277.000000     100.000000          7.000000  ...    133.000000
#
#          ucz_ogolem  w tym_ucz_dziewczeta  w tym_w oddz_przedszk  \
# count  39207.000000          38654.000000           22279.000000
# mean     173.251639             86.805738              65.188429
# std      209.847911            115.922413              56.668957
# min        1.000000              1.000000               1.000000
# 25%       48.000000             22.000000              23.000000
# 50%      105.000000             51.000000              47.000000
# 75%      211.000000            104.000000              94.000000
# max    13284.000000           8610.000000             681.000000
#
#             lb_oddz     etatUmowa  w tym_etat_niepełnozatr  lb_naucz_osoby  \
# count  39207.000000  30298.000000             30298.000000    30298.000000
# mean       9.052899     23.940488                 3.391046       27.828702
# std        8.162324     23.311713                 3.913951       24.642672
# min        1.000000      0.000000                 0.000000        1.000000
# 25%        3.000000      8.000000                 0.860000       11.000000
# 50%        7.000000     16.555000                 2.330000       21.000000
# 75%       11.000000     33.170000                 4.610000       38.000000
# max      126.000000    320.470000                99.090000      326.000000
#
#        w tym_lb_naucz_pelnozatr  w tym_lb_naucz_niepelnozatr
# count              30298.000000                 30298.000000
# mean                  20.506799                     7.321902
# std                   21.685926                     7.699949
# min                    0.000000                     0.000000
# 25%                    6.000000                     2.000000
# 50%                   13.000000                     5.000000
# 75%                   29.000000                    10.000000
# max                  313.000000                   211.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# ## Selecting rows and columns
#
# ### First row - school name

# %%
# First row
row = df.iloc[0]
row
# Out:
# Rok szkolny                                                                  2024/2025
# idTerytWojewodztwo                                                                   2
# Wojewodztwo                                                               DOLNOŚLĄSKIE
# idTerytPowiat                                                                      201
# Powiat                                                                   bolesławiecki
# idTerytGmina                                                                    201011
# Gmina                                                                      Bolesławiec
# Typ gminy                                                                            M
# Miejscowość                                                                Bolesławiec
# Czy szkoła                                                                           0
# idPodmiotGlowny                                                                   3845
# idPodmiotNadrzedny                                                                 NaN
# idTypPodmiotuNadrzednego                                                           NaN
# Typ podmiotu nadrzędnego                                                           NaN
# RSPO                                                                              3845
# idTypPodmiotu                                                                      100
# Typ podmiotu                                       Zespół szkół i placówek oświatowych
# idRodzajPlacowki                                                                     6
# Rodzaj szkoły/placówki                                               jednostka złożona
# Nazwa placówki                       ZESPÓŁ SZKÓŁ OGÓLNOKSZTAŁCĄCYCH I ZAWODOWYCH I...
# Ulica                                                             ul. Komuny Paryskiej
# Numer domu                                                                           6
# Numer lokalu                                                                       NaN
# Kod pocztowy                                                                    59-700
# Poczta                                                                     Bolesławiec
# Adres www                                               www.sucharski.boleslawianie.pl
# regon                                                                           178778
# idPublicznosc                                                                        1
# Publiczność                                                                  publiczna
# idKategoriaUczniow                                                                   3
# Kategoria uczniów                                                        Bez kategorii
# idSpecyfikaSzkoly                                                                  100
# Specyfika szkoły                                                        brak specyfiki
# idZwiazanieOrganizacyjneSzkoly                                                     NaN
# Związanie organizacyjne                                                            NaN
# idTypOrgProw                                                                       132
# Typ organu prowadzącego                                                 Powiat ziemski
# typ_org_prow                                                                       jst
# idOrganProwadzacy                                                                 2473
# Organ prowadzący                                                  POWIAT BOLESŁAWIECKI
# idTerytWojewOrgRej                                                                 2.0
# Organ rejestrującey - województwo                                         DOLNOŚLĄSKIE
# idTerytPowiatOrgRej                                                              201.0
# Organ rejestrujący - powiat                                              bolesławiecki
# idTerytGminaOrgRej                                                                 NaN
# Organ rejestrujący - gmina                                                         NaN
# idTypOrgRej                                                                        132
# Typ organu rejestrującego                                               Powiat ziemski
# Organ rejestrujący                                                POWIAT BOLESŁAWIECKI
# ucz_ogolem                                                                         NaN
# w tym_ucz_dziewczeta                                                               NaN
# w tym_w oddz_przedszk                                                              NaN
# lb_oddz                                                                            NaN
# etatUmowa                                                                        47.33
# w tym_etat_niepełnozatr                                                           6.33
# lb_naucz_osoby                                                                    56.0
# w tym_lb_naucz_pelnozatr                                                          41.0
# w tym_lb_naucz_niepelnozatr                                                       15.0
# Name: 0, dtype: object

# %%
# School name
row['Nazwa placówki']
# Out:
# 'ZESPÓŁ SZKÓŁ OGÓLNOKSZTAŁCĄCYCH I ZAWODOWYCH IM. MJRA H. SUCHARSKIEGO W BOLESŁAWCU'

# %% [markdown]
# ### Select rows - websites
#
# All schools that have a website listed.

# %%
with_website = df.loc[df['Adres www'].notna()]
with_website['Adres www'].count()
# Out:
# np.int64(41471)

# %%
# School name and website address
with_website[['Nazwa placówki', 'Adres www']].head(20)
# Out:
#                                        Nazwa placówki  \
# 0   ZESPÓŁ SZKÓŁ OGÓLNOKSZTAŁCĄCYCH I ZAWODOWYCH I...
# 2                         TECHNIKUM NR 3 W BOLESŁAWCU
# 3       CENTRUM KSZTAŁCENIA USTAWICZNEGO W BOLESŁAWCU
# 4         BRANŻOWA SZKOŁA I STOPNIA NR 3 W BOLESŁAWCU
# 5             BRANŻOWA SZKOŁA II STOPNIA W BOLESŁAWCU
# 6   II LICEUM OGÓLNOKSZTAŁCĄCE IM. J. KORCZAKA W B...
# 7   ZESPÓŁ SZKÓŁ MECHANICZNYCH IM. L. WARYŃSKIEGO ...
# 8                         TECHNIKUM NR 1 W BOLESŁAWCU
# 9         BRANŻOWA SZKOŁA I STOPNIA NR 1 W BOLESŁAWCU
# 10              ZESPÓŁ SZKÓŁ BUDOWLANYCH W BOLESŁAWCU
# 11                        TECHNIKUM NR 2 W BOLESŁAWCU
# 12        BRANŻOWA SZKOŁA I STOPNIA NR 2 W BOLESŁAWCU
# 13  POWIATOWY ZESPÓŁ SZKÓŁ I PLACÓWEK SPECJALNYCH ...
# 14  POWIATOWA SZKOŁA PODSTAWOWA SPECJALNA W BOLESŁ...
# 15  POWIATOWA SZKOŁA SPECJALNA PRZYSPOSABIAJĄCA DO...
# 16     OŚRODEK REWALIDACYJNO-WYCHOWAWCZY W BOLESŁAWCU
# 18  POWIATOWE CENTRUM EDUKACJI I KSZTAŁCENIA KADR ...
# 20  POWIATOWY OŚRODEK DOSKONALENIA NAUCZYCIELI W B...
# 22  NIEPUBLICZNA BURSA IM. ŚW. MARII DE MATTIAS ZG...
# 23                    STUDIUM POLICEALNE W BOLESŁAWCU
#
#                          Adres www
# 0   www.sucharski.boleslawianie.pl
# 2   www.sucharski.boleslawianie.pl
# 3               cku.boleslawiec.pl
# 4   www.sucharski.boleslawianie.pl
# 5      http://www.sucharski.edu.pl
# 6           www.lo2.boleslawiec.pl
# 7                 www.zsmbc.eu.org
# 8                 www.zsmbc.eu.org
# 9                 www.zsmbc.eu.org
# 10          www.zsb.boleslawiec.pl
# 11          www.zsb.boleslawiec.pl
# 12          www.zsb.boleslawiec.pl
# 13     pzsips.bol.szkolnastrona.pl
# 14     pzsips.bol.szkolnastrona.pl
# 15     pzsips.bol.szkolnastrona.pl
# 16     pzsips.bol.szkolnastrona.pl
# 18  https://boleslawiec.pceikk.pl/
# 20  https://boleslawiec.pceikk.pl/
# 22               www.adoratorki.pl
# 23              www.aurelus.edu.pl

# %% [markdown]
# ## Data manipulation
#
# ### Website address length

# %%
df_www = with_website[['Nazwa placówki', 'Adres www']].copy()
# Out:
#                                           Nazwa placówki  \
# 0      ZESPÓŁ SZKÓŁ OGÓLNOKSZTAŁCĄCYCH I ZAWODOWYCH I...
# 2                            TECHNIKUM NR 3 W BOLESŁAWCU
# 3          CENTRUM KSZTAŁCENIA USTAWICZNEGO W BOLESŁAWCU
# 4            BRANŻOWA SZKOŁA I STOPNIA NR 3 W BOLESŁAWCU
# 5                BRANŻOWA SZKOŁA II STOPNIA W BOLESŁAWCU
# ...                                                  ...
# 55639  PRZEDSZKOLE NIEPUBLICZNE "WIATRACZEK" W ŚWINOU...
# 55640  BRANŻOWA SZKOŁA I STOPNIA A.K.S. SZKOŁA TECHNI...
# 55641  BRANŻOWA SZKOŁA II STOPNIA A.K.S. SZKOŁA TECHN...
# 55642  BRANŻOWA SZKOŁA II STOPNIA W ŚWINOUJŚCIU WOJEW...
# 55644  NIEPUBLICZNE LICEUM OGÓLNOKSZTAŁCĄCE SZKOŁA BE...
#
#                                Adres www
# 0         www.sucharski.boleslawianie.pl
# 2         www.sucharski.boleslawianie.pl
# 3                     cku.boleslawiec.pl
# 4         www.sucharski.boleslawianie.pl
# 5            http://www.sucharski.edu.pl
# ...                                  ...
# 55639       www.przedszkolewiatraczek.pl
# 55640                  www.aks.szkola.pl
# 55641                  www.aks.szkola.pl
# 55642  http://swinoujscie.wzdz.pl/szkola
# 55644            www.szkola-bezgranic.pl
#
# [41471 rows x 2 columns]

# %%
# Website address length
df_www['Długość adresu www'] = df_www['Adres www'].map(lambda x: len(x))
df_www
# Out:
#                                           Nazwa placówki  \
# 0      ZESPÓŁ SZKÓŁ OGÓLNOKSZTAŁCĄCYCH I ZAWODOWYCH I...
# 2                            TECHNIKUM NR 3 W BOLESŁAWCU
# 3          CENTRUM KSZTAŁCENIA USTAWICZNEGO W BOLESŁAWCU
# 4            BRANŻOWA SZKOŁA I STOPNIA NR 3 W BOLESŁAWCU
# 5                BRANŻOWA SZKOŁA II STOPNIA W BOLESŁAWCU
# ...                                                  ...
# 55639  PRZEDSZKOLE NIEPUBLICZNE "WIATRACZEK" W ŚWINOU...
# 55640  BRANŻOWA SZKOŁA I STOPNIA A.K.S. SZKOŁA TECHNI...
# 55641  BRANŻOWA SZKOŁA II STOPNIA A.K.S. SZKOŁA TECHN...
# 55642  BRANŻOWA SZKOŁA II STOPNIA W ŚWINOUJŚCIU WOJEW...
# 55644  NIEPUBLICZNE LICEUM OGÓLNOKSZTAŁCĄCE SZKOŁA BE...
#
#                                Adres www  Długość adresu www
# 0         www.sucharski.boleslawianie.pl                  30
# 2         www.sucharski.boleslawianie.pl                  30
# 3                     cku.boleslawiec.pl                  18
# 4         www.sucharski.boleslawianie.pl                  30
# 5            http://www.sucharski.edu.pl                  27
# ...                                  ...                 ...
# 55639       www.przedszkolewiatraczek.pl                  28
# 55640                  www.aks.szkola.pl                  17
# 55641                  www.aks.szkola.pl                  17
# 55642  http://swinoujscie.wzdz.pl/szkola                  33
# 55644            www.szkola-bezgranic.pl                  23
#
# [41471 rows x 3 columns]

# %%
df_www_length = df_www.copy()
df_www_length.drop('Adres www', axis=1, inplace=True)
df_www_length
# Out:
#                                           Nazwa placówki  Długość adresu www
# 0      ZESPÓŁ SZKÓŁ OGÓLNOKSZTAŁCĄCYCH I ZAWODOWYCH I...                  30
# 2                            TECHNIKUM NR 3 W BOLESŁAWCU                  30
# 3          CENTRUM KSZTAŁCENIA USTAWICZNEGO W BOLESŁAWCU                  18
# 4            BRANŻOWA SZKOŁA I STOPNIA NR 3 W BOLESŁAWCU                  30
# 5                BRANŻOWA SZKOŁA II STOPNIA W BOLESŁAWCU                  27
# ...                                                  ...                 ...
# 55639  PRZEDSZKOLE NIEPUBLICZNE "WIATRACZEK" W ŚWINOU...                  28
# 55640  BRANŻOWA SZKOŁA I STOPNIA A.K.S. SZKOŁA TECHNI...                  17
# 55641  BRANŻOWA SZKOŁA II STOPNIA A.K.S. SZKOŁA TECHN...                  17
# 55642  BRANŻOWA SZKOŁA II STOPNIA W ŚWINOUJŚCIU WOJEW...                  33
# 55644  NIEPUBLICZNE LICEUM OGÓLNOKSZTAŁCĄCE SZKOŁA BE...                  23
#
# [41471 rows x 2 columns]
